# %% [markdown]
# # <span style='color:aliceblue'><center style='background:#000000 border-radius:0px 25px;padding:25px'> 💤💨💦Part 3. Dictionaries and Sets✨❄️🌻</center></span>

# %% [markdown]
# ### Use the marco geoestadístico 2010 (https://www.inegi.org.mx/app/biblioteca/ficha.html?upc=889463807469)     and 2020 (https://www.inegi.org.mx/app/biblioteca/ficha.html?upc=702825292812) to obtain the “Áreas Geoestadísticas Básicas”(AGEBs) from Mérida, Yucatán. AGEBs evolve on time. Use sets to find:

# %% [markdown]
# - `geopandas` is imported with the alias `gpd`.
# - Two variables, `file_mex_2010` and `file_yuc_2020`, are defined, each holding the path to a specific Shapefile.

# %%
import geopandas as gpd

file_mex_2010 = '2010_MEX\AGEB_urb_2010_5.shp'
file_yuc_2020 = '2020_YUC\conjunto_de_datos\\31a.shp'

# %% [markdown]
# This code segment uses the geopandas library to read a Shapefile and load the geospatial data into a GeoDataFrame.

# %%
mex_2010 = gpd.read_file(file_mex_2010)
mex_2010
# Out:
#         CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0      LA_6052  0100100013204  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1      LA_6052  0100100013721  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2      LA_6052  0100100010657  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3      LA_6052  0100100011528  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4      LA_6052  0100100011674  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ...        ...            ...                         ...      ...       ...
# 56190  LA_6052  3205800010087  ÁREA GEOESTADÍSTICA BÁSICA  06/2009      ÁREA
# 56191  LA_6052  3205800010104  ÁREA GEOESTADÍSTICA BÁSICA  06/2009      ÁREA
# 56192  LA_6052  320580001002A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 56193  LA_6052  3205800010015  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 56194  LA_6052  3205800010072  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
# ...

# %% [markdown]
# This code snippet is manipulating a `GeoDataFrame` named `mex_2010`, which contains geospatial data previously loaded from a Shapefile. Specifically, it's extracting and creating a new column based on existing data:

# %%
mex_2010["CVE_ENT"] = mex_2010['CVEGEO'].str.slice(0,2)
mex_2010
# Out:
#         CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0      LA_6052  0100100013204  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1      LA_6052  0100100013721  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2      LA_6052  0100100010657  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3      LA_6052  0100100011528  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4      LA_6052  0100100011674  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ...        ...            ...                         ...      ...       ...
# 56190  LA_6052  3205800010087  ÁREA GEOESTADÍSTICA BÁSICA  06/2009      ÁREA
# 56191  LA_6052  3205800010104  ÁREA GEOESTADÍSTICA BÁSICA  06/2009      ÁREA
# 56192  LA_6052  320580001002A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 56193  LA_6052  3205800010015  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 56194  LA_6052  3205800010072  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
# ...

# %% [markdown]
# This line of code continues the manipulation of the `mex_2010` GeoDataFrame, which contains geospatial data.

# %%
mex_2010["CVE_MUN"] = mex_2010["CVEGEO"].str.slice(2,5)
mex_2010
# Out:
#         CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0      LA_6052  0100100013204  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1      LA_6052  0100100013721  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2      LA_6052  0100100010657  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3      LA_6052  0100100011528  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4      LA_6052  0100100011674  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ...        ...            ...                         ...      ...       ...
# 56190  LA_6052  3205800010087  ÁREA GEOESTADÍSTICA BÁSICA  06/2009      ÁREA
# 56191  LA_6052  3205800010104  ÁREA GEOESTADÍSTICA BÁSICA  06/2009      ÁREA
# 56192  LA_6052  320580001002A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 56193  LA_6052  3205800010015  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 56194  LA_6052  3205800010072  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
# ...

# %% [markdown]
# This code snippet filters the `mex_2010` GeoDataFrame to select only the rows where the `"CVE_ENT"` column equals `'31'`, which represents the entities within the state of Yucatán, given that '31' is the code for Yucatán in Mexico's geographical coding system. The filtered data is then assigned to a new GeoDataFrame named `yuc_2010_data`.

# %%
yuc_2010_data = mex_2010[mex_2010['CVE_ENT'] == '31']
yuc_2010_data
# Out:
#         CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 52973  LA_6052  3100100010130  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 52974  LA_6052  3100100010126  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 52975  LA_6052  3100100010111  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 52976  LA_6052  3100100010164  ÁREA GEOESTADÍSTICA BÁSICA  08/2010      ÁREA
# 52977  LA_6052  3100100010145  ÁREA GEOESTADÍSTICA BÁSICA  08/2010      ÁREA
# ...        ...            ...                         ...      ...       ...
# 54408  LA_6052  3110500010065  ÁREA GEOESTADÍSTICA BÁSICA  10/2010      ÁREA
# 54409  LA_6052  3110500010027  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 54410  LA_6052  3110600010043  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 54411  LA_6052  3110600010077  ÁREA GEOESTADÍSTICA BÁSICA  10/2010      ÁREA
# 54412  LA_6052  3110600010058  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
# ...

# %% [markdown]
# This line of code further filters the `yuc_2010_data` GeoDataFrame, narrowing down the selection to only include the rows where the `"CVE_MUN"` column equals `'050'`. This specific operation isolates data for a particular municipality within the state of Yucatán, with the municipality code `'050'` referring to Mérida, the capital and largest city of Yucatán. The filtered data is then stored in a new GeoDataFrame named `merida_2010`.

# %%
merida_2010 = yuc_2010_data[yuc_2010_data["CVE_MUN"] == "050"]
merida_2010
# Out:
#         CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 53392  LA_6052  310500001516A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53393  LA_6052  3105000012625  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53394  LA_6052  3105000012697  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53395  LA_6052  3105000013572  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53396  LA_6052  3105000015649  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ...        ...            ...                         ...      ...       ...
# 53861  LA_6052  3105001116276  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 53862  LA_6052  3105001116280  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 53863  LA_6052  3105001116295  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 53864  LA_6052  3105004086596  ÁREA GEOESTADÍSTICA BÁSICA  06/2010      ÁREA
# 53865  LA_6052  3105004086609  ÁREA GEOESTADÍSTICA BÁSICA  06/2010      ÁREA
#
# ...

# %% [markdown]
# This snippet of code reads a Shapefile related to Yucatán for the year 2020 and stores its data in a `GeoDataFrame` named `yuc_2020`:

# %%
yuc_2020 = gpd.read_file(file_yuc_2020)
yuc_2020
# Out:
#              CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 0     3100100010130      31     001    0001     0130
# 1     3100100010145      31     001    0001     0145
# 2     3100100010164      31     001    0001     0164
# 3     3100100010126      31     001    0001     0126
# 4     3100100010107      31     001    0001     0107
# ...             ...     ...     ...     ...      ...
# 1527  3101900630421      31     019    0063     0421
# 1528  3101900630436      31     019    0063     0436
# 1529  3101900620012      31     019    0062     0012
# 1530  3101900620031      31     019    0062     0031
# 1531  3101900620046      31     019    0062     0046
#
#                                                geometry
# 0     POLYGON ((3776847.045 1015576.473, 3776850.565...
# 1     POLYGON ((3776745.860 1015499.562, 3776745.439...
# 2     POLYGON ((3776136.004 1014614.653, 3776022.228...
# 3     POLYGON ((3776247.740 1014594.755, 3776229.182...
# ...

# %% [markdown]
# This line of code filters the `yuc_2020` GeoDataFrame to select only the rows where the `"CVE_MUN"` column equals `'050'`, which likely represents the municipality code for Mérida in the state of Yucatán for the year 2020. The filtered data is then assigned to a new GeoDataFrame named `merida_2020`.

# %%
merida_2020 = yuc_2020[yuc_2020["CVE_MUN"] == "050"]
merida_2020
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 412  3105000015329      31     050    0001     5329
# 413  3105000012466      31     050    0001     2466
# 414  310500001249A      31     050    0001     249A
# 415  3105000015827      31     050    0001     5827
# 416  3105000014706      31     050    0001     4706
# ..             ...     ...     ...     ...      ...
# 933  3105000017039      31     050    0001     7039
# 934  3105000014049      31     050    0001     4049
# 935  3105000010864      31     050    0001     0864
# 936  310500001085A      31     050    0001     085A
# 937  3105000010879      31     050    0001     0879
#
#                                               geometry
# 412  POLYGON ((3779478.623 1047307.492, 3779480.973...
# 413  POLYGON ((3777875.435 1056949.722, 3777947.632...
# 414  POLYGON ((3779713.782 1053802.753, 3779711.800...
# 415  POLYGON ((3772091.762 1052572.146, 3772125.684...
# 416  POLYGON ((3772829.128 1047931.320, 3772821.774...
# ...

# %% [markdown]
# This code segment performs a set operation on two GeoDataFrames (`merida_2010` and `merida_2020`), extracting the unique 'CVEGEO' values for Mérida from two different years (2010 and 2020) and printing these sets for comparison:
#
# 1. **Create Sets of Unique Identifiers**:
#    - `merida_2010_set = set(merida_2010['CVEGEO'])`: Converts the 'CVEGEO' column values from the `merida_2010` GeoDataFrame into a set, effectively removing any duplicates and storing unique geographic codes for Mérida in 2010.
#    - `merida_2020_set = set(merida_2020['CVEGEO'])`: Does the same for the `merida_2020` GeoDataFrame, storing unique geographic codes for Mérida in 2020.
#
# 2. **Print Sets**:
#    - The `print` statements then display these sets, labeled as `merida_2010_set` and `merida_2020_set`, respectively. This provides a clear textual representation of the unique geographic identifiers used in both years, allowing for a straightforward comparison of what has remained the same, what has changed, or what has been added or removed between 2010 and 2020.

# %%
merida_2010_set = set(merida_2010['CVEGEO'])
merida_2020_set = set(merida_2020['CVEGEO'])


print("merida_2010_set:", merida_2010_set)
print("merida_2020_set:", merida_2020_set)
# Out:
# merida_2010_set: {'3105000011472', '3105000012875', '3105000014994', '3105000014231', '3105000014227', '3105000015846', '3105000010347', '3105000016064', '3105000010718', '3105000016187', '3105000012288', '3105000012324', '3105000015935', '310500001651A', '3105000010262', '3105000010489', '3105000016261', '310500001594A', '3105000013784', '3105000011773', '3105000012409', '3105000016539', '310500001523A', '3105000012979', '3105000776331', '3105000014706', '3105000010493', '3105000014068', '3105000013271', '3105000012610', '3105000013106', '3105000011241', '3105000014636', '3105000015102', '3105000012729', '3105000012574', '3105000014903', '310500001224A', '3105000014335', '3105000013159', '3105000932127', '3105000015117', '3105000015808', '3105001116295', '3105000015969', '3105000012856', '3105000014496', '3105000775530', '3105000011576', '3105000014477', '3105000011608', '3105000012945', '3105000014814', '3105000016384', '3105000012625', '3105000016350', '3105000011523', '3105000016
# ...

# %% [markdown]
# This snippet of code uses set operations to analyze the differences and similarities in geographic codes ('CVEGEO') for Mérida between the years 2010 and 2020, effectively identifying which areas remained unchanged, which are new, and which disappeared over the decade.

# %%
remains_2010_2020 = merida_2010_set & merida_2010_set
new_in_2020 = merida_2020_set - merida_2010_set
disappears_2010_2020 = merida_2010_set - merida_2020_set

# %% [markdown]
# This code snippet filters the `merida_2020` GeoDataFrame to create a new GeoDataFrame, `remains_2010_2020_gdf`, which contains only the areas that remained unchanged between 2010 and 2020 in Mérida, based on their 'CVEGEO' geographic codes.

# %%
remains_2010_2020_gdf = merida_2020[merida_2020["CVEGEO"].isin(remains_2010_2020)]
remains_2010_2020_gdf
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 412  3105000015329      31     050    0001     5329
# 413  3105000012466      31     050    0001     2466
# 414  310500001249A      31     050    0001     249A
# 415  3105000015827      31     050    0001     5827
# 416  3105000014706      31     050    0001     4706
# ..             ...     ...     ...     ...      ...
# 925  3105000015386      31     050    0001     5386
# 927  3105000015899      31     050    0001     5899
# 928  3105000015884      31     050    0001     5884
# 929  3105000016350      31     050    0001     6350
# 934  3105000014049      31     050    0001     4049
#
#                                               geometry
# 412  POLYGON ((3779478.623 1047307.492, 3779480.973...
# 413  POLYGON ((3777875.435 1056949.722, 3777947.632...
# 414  POLYGON ((3779713.782 1053802.753, 3779711.800...
# 415  POLYGON ((3772091.762 1052572.146, 3772125.684...
# 416  POLYGON ((3772829.128 1047931.320, 3772821.774...
# ...

# %% [markdown]
# This code snippet is creating a new GeoDataFrame named `new_in_2020_gdf` by filtering the `merida_2020` GeoDataFrame. It includes only those areas that are new in Mérida for the year 2020, based on their 'CVEGEO' geographic codes, which did not appear in the 2010 dataset.

# %%
new_in_2020_gdf = merida_2020[merida_2020["CVEGEO"].isin(new_in_2020)]
new_in_2020_gdf
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 425  3105000016736      31     050    0001     6736
# 524  3105000016755      31     050    0001     6755
# 652  3105000016825      31     050    0001     6825
# 789  3105000016632      31     050    0001     6632
# 790  3105000016666      31     050    0001     6666
# 791  3105000016721      31     050    0001     6721
# 792  310500001683A      31     050    0001     683A
# 805  3105000016647      31     050    0001     6647
# 807  310500001690A      31     050    0001     690A
# 808  3105000016948      31     050    0001     6948
# 809  3105000016990      31     050    0001     6990
# 810  3105000017005      31     050    0001     7005
# 811  3105000016967      31     050    0001     6967
# 813  3105000014744      31     050    0001     4744
# 814  3105000014778      31     050    0001     4778
# 815  3105000845352      31     050    0084     5352
# 826  3105000016670      31     050    0001     6670
# ...

# %% [markdown]
# This line of code filters the `merida_2010` GeoDataFrame to create a new GeoDataFrame, `disappears_2010_2020_gdf`, which includes only those areas that disappeared from Mérida between the years 2010 and 2020. This is based on their 'CVEGEO' geographic codes, which were present in the 2010 dataset but not in the 2020 dataset.

# %%
disappears_2010_2020_gdf = merida_2010[merida_2010["CVEGEO"].isin(disappears_2010_2020)]
disappears_2010_2020_gdf
# Out:
#         CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 53419  LA_6052  3105000012752  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53420  LA_6052  3105000012767  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53464  LA_6052  3105000013835  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53503  LA_6052  3105000013534  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53611  LA_6052  3105000015507  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53864  LA_6052  3105004086596  ÁREA GEOESTADÍSTICA BÁSICA  06/2010      ÁREA
# 53865  LA_6052  3105004086609  ÁREA GEOESTADÍSTICA BÁSICA  06/2010      ÁREA
#
#       INSTITUCIO    OID                                           geometry  \
# 53419      INEGI  53420  POLYGON ((3786348.565 1052307.955, 3786352.052...
# 53420      INEGI  53421  POLYGON ((3786173.535 1051314.772, 3786174.142...
# 53464      INEGI  53465  POLYGON ((3782889.085 1045565.743, 3782899.339...
# ...

# %% [markdown]
# This code snippet uses `matplotlib` and `geopandas` to create a visual map displaying the changes in the AGEBs (Áreas Geoestadísticas Básicas) of Mérida from 2010 to 2020. It categorizes the AGEBs into three groups based on whether they remained unchanged, appeared new in 2020, or disappeared from 2010 to 2020, and plots each category with distinct colors for clear differentiation.

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

fig, ax = plt.subplots(1, 1, figsize=(10, 8))

# Plot your data with updated colors
remains_2010_2020_gdf.plot(ax=ax, color='blue', edgecolor='white', linewidth=0.5, alpha=0.8, label='Remains 2010-2020')  # Remains in light blue
new_in_2020_gdf.plot(ax=ax, color='purple', edgecolor='white', linewidth=0.5, alpha=0.8, label='New in 2020')  # New in purple
disappears_2010_2020_gdf.plot(ax=ax, color='magenta', edgecolor='white', linewidth=0.5, alpha=0.8, label='Disappeared 2010-2020')  # Disappeared in pink

# Create custom legend with the updated colors
legend_labels = [
    Patch(facecolor='lightblue', edgecolor='white', label='Remains 2010-2020'),
    Patch(facecolor='purple', edgecolor='white', label='New in 2020'),
    Patch(facecolor='pink', edgecolor='white', label='Disappeared 2010-2020')
]
ax.legend(handles=legend_labels)

# Customizations
ax.set_title('AGEB changes from 2010 to 2020')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.grid(True)

plt.show()
